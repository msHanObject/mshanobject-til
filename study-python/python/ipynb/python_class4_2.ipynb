# %%
import pandas as pd

# %%
df = pd.read_csv('subway.csv',encoding = 'euc-kr')

# %%
df
# Out:
#             역명          날짜  구분 05~06시 06~07시 07~08시  08~09시 09~10시 10~11시  \
# 0     서울역(150)  2017-04-01  승차    493    513    654   1,517  2,104  2,522
# 1     서울역(150)  2017-04-01  하차    385  2,074  1,923   2,511  3,377  3,021
# 2     서울역(150)  2017-04-02  승차    342    340    413     944  1,533  1,734
# 3     서울역(150)  2017-04-02  하차    197  1,229  1,119   1,369  1,958  1,996
# 4     서울역(150)  2017-04-03  승차    467    603  2,137   3,296  2,121  2,094
# 5     서울역(150)  2017-04-03  하차    376  2,566  5,344  10,582  5,197  2,622
# 6     서울역(150)  2017-04-04  승차    443    573  1,611   2,916  2,048  2,100
# 7     서울역(150)  2017-04-04  하차    324  2,015  4,937  10,254  5,196  2,710
# 8     서울역(150)  2017-04-05  승차    415    572  1,685   2,953  2,072  2,090
# 9     서울역(150)  2017-04-05  하차    296  2,015  4,450  10,375  5,615  2,491
# 10    서울역(150)  2017-04-06  승차    378    545  1,595   2,965  2,034  2,088
# 11    서울역(150)  2017-04-06  하차    308  2,021  4,572  10,241  5,602  2,809
# ...

# %%
sdf = df[(df['구분'] == '승차')]

# %%
sdf
# Out:
#             역명          날짜  구분 05~06시 06~07시 07~08시 08~09시 09~10시 10~11시  \
# 0     서울역(150)  2017-04-01  승차    493    513    654  1,517  2,104  2,522
# 2     서울역(150)  2017-04-02  승차    342    340    413    944  1,533  1,734
# 4     서울역(150)  2017-04-03  승차    467    603  2,137  3,296  2,121  2,094
# 6     서울역(150)  2017-04-04  승차    443    573  1,611  2,916  2,048  2,100
# 8     서울역(150)  2017-04-05  승차    415    572  1,685  2,953  2,072  2,090
# 10    서울역(150)  2017-04-06  승차    378    545  1,595  2,965  2,034  2,088
# 12    서울역(150)  2017-04-07  승차    475    580  1,633  2,772  2,422  2,030
# 14    서울역(150)  2017-04-08  승차    480    532    717  1,637  2,417  2,422
# 16    서울역(150)  2017-04-09  승차    335    352    449    997  1,573  1,939
# 18    서울역(150)  2017-04-10  승차    539    653  2,019  3,321  2,087  2,286
# 20    서울역(150)  2017-04-11  승차    455    598  1,673  2,909  2,091  2,073
# 22    서울역(150)  2017-04-12  승차    443    573  1,673  2,934  2,009  2,058
# ...

# %%
hsf = df[(df['구분'] == '하차')]

# %%
sdf.count()
# Out:
# 역명        3570
# 날짜        3570
# 구분        3570
# 05~06시    3570
# 06~07시    3570
# 07~08시    3570
# 08~09시    3570
# 09~10시    3570
# 10~11시    3570
# 11~12시    3570
# 12~13시    3570
# 13~14시    3570
# 14~15시    3570
# 15~16시    3570
# 16~17시    3570
# 17~18시    3570
# 18~19시    3570
# 19~20시    3570
# 20~21시    3570
# 21~22시    3570
# 22~23시    3570
# 23~24시    3570
# 00~01시    3570
# 01~02시    3570
# dtype: int64

# %%
sdf.max()
# Out:
# 역명           회현(425)
# 날짜        2017-04-30
# 구분                승차
# 05~06시           997
# 06~07시           997
# 07~08시           998
# 08~09시           999
# 09~10시           999
# 10~11시           999
# 11~12시           999
# 12~13시           999
# 13~14시           999
# 14~15시           999
# 15~16시           997
# 16~17시           999
# 17~18시           999
# 18~19시           996
# 19~20시           999
# 20~21시           998
# 21~22시           998
# 22~23시           998
# 23~24시           997
# 00~01시            99
# 01~02시             9
# dtype: object

# %%
sdf.argmax('06~07시')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-269378ca07e2> in <module>()
# ----> 1 sdf.argmax('06~07시')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'argmax'
