# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/nulgrace/workspace/python/res/olympics.csv')

# %%
df.head()
# Out:
#                    0         1     2     3     4      5         6     7     8  \
# 0                NaN  № Summer  01 !  02 !  03 !  Total  № Winter  01 !  02 !
# 1  Afghanistan (AFG)        13     0     0     2      2         0     0     0
# 2      Algeria (ALG)        12     5     2     8     15         3     0     0
# 3    Argentina (ARG)        23    18    24    28     70        18     0     0
# 4      Armenia (ARM)         5     1     2     9     12         6     0     0
#
#       9     10       11    12    13    14              15
# 0  03 !  Total  № Games  01 !  02 !  03 !  Combined total
# 1     0      0       13     0     0     2               2
# 2     0      0       15     5     2     8              15
# 3     0      0       41    18    24    28              70
# 4     0      0       11     1     2     9              12

# %%
df = pd.read_csv('/Users/nulgrace/workspace/python/res/olympics.csv', index_col = 0, skiprows = 1)

# %%
df.head()
# Out:
#                          № Summer  01 !  02 !  03 !  Total  № Winter  01 !.1  \
# Afghanistan (AFG)              13     0     0     2      2         0       0
# Algeria (ALG)                  12     5     2     8     15         3       0
# Argentina (ARG)                23    18    24    28     70        18       0
# Armenia (ARM)                   5     1     2     9     12         6       0
# Australasia (ANZ) [ANZ]         2     3     4     5     12         0       0
#
#                          02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  \
# Afghanistan (AFG)             0       0        0       13       0       0
# Algeria (ALG)                 0       0        0       15       5       2
# Argentina (ARG)               0       0        0       41      18      24
# Armenia (ARM)                 0       0        0       11       1       2
# Australasia (ANZ) [ANZ]       0       0        0        2       3       4
#
#                          03 !.2  Combined total
# ...

# %%
df.columns
# Out:
# Index(['№ Summer', '01 !', '02 !', '03 !', 'Total', '№ Winter', '01 !.1',
#        '02 !.1', '03 !.1', 'Total.1', '№ Games', '01 !.2', '02 !.2', '03 !.2',
#        'Combined total'],
#       dtype='object')

# %%
for col in df.columns:
    if col[:2] == '01':
        df.rename(columns={col: 'Gold' + col[4:]}, inplace=True)
    if col[:2] == '02':
        df.rename(columns={col: 'Sivler' + col[4:]}, inplace=True)
    if col[:2] == '03':
        df.rename(columns={col: 'Bronze' + col[4:]}, inplace=True)
    if col[:1] == '№':
        df.rename(columns={col: '#' + col[2:]}, inplace=True)

# %%
df.count()
# Out:
# #Summer           147
# Gold              147
# Sivler            147
# Bronze            147
# Total             147
# #Winter           147
# Gold.1            147
# Sivler.1          147
# Bronze.1          147
# Total.1           147
# #Games            147
# Gold.2            147
# Sivler.2          147
# Bronze.2          147
# Combined total    147
# dtype: int64

# %%
df.head()
# Out:
#                          #Summer  Gold  Sivler  Bronze  Total  #Winter  \
# Afghanistan (AFG)             13     0       0       2      2        0
# Algeria (ALG)                 12     5       2       8     15        3
# Argentina (ARG)               23    18      24      28     70       18
# Armenia (ARM)                  5     1       2       9     12        6
# Australasia (ANZ) [ANZ]        2     3       4       5     12        0
#
#                          Gold.1  Sivler.1  Bronze.1  Total.1  #Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0      13       0
# Algeria (ALG)                 0         0         0        0      15       5
# Argentina (ARG)               0         0         0        0      41      18
# Armenia (ARM)                 0         0         0        0      11       1
# Australasia (ANZ) [ANZ]       0         0         0        0       2       3
#
#                          Sivler.2  Bronze.2  Combined total
# ...

# %%
df = df.drop('Total', axis=1)

# %%
df.head()
# Out:
#                          #Summer  Gold  Sivler  Bronze  #Winter  Gold.1  \
# Afghanistan (AFG)             13     0       0       2        0       0
# Algeria (ALG)                 12     5       2       8        3       0
# Argentina (ARG)               23    18      24      28       18       0
# Armenia (ARM)                  5     1       2       9        6       0
# Australasia (ANZ) [ANZ]        2     3       4       5        0       0
#
#                          Sivler.1  Bronze.1  Total.1  #Games  Gold.2  \
# Afghanistan (AFG)               0         0        0      13       0
# Algeria (ALG)                   0         0        0      15       5
# Argentina (ARG)                 0         0        0      41      18
# Armenia (ARM)                   0         0        0      11       1
# Australasia (ANZ) [ANZ]         0         0        0       2       3
#
#                          Sivler.2  Bronze.2  Combined total
# ...

# %%
df.iloc[0]
# Out:
# #Summer           13
# Gold               0
# Sivler             0
# Bronze             2
# #Winter            0
# Gold.1             0
# Sivler.1           0
# Bronze.1           0
# Total.1            0
# #Games            13
# Gold.2             0
# Sivler.2           0
# Bronze.2           2
# Combined total     2
# Name: Afghanistan (AFG), dtype: int64

# %%
df['Gold']
# Out:
# Afghanistan (AFG)                                  0
# Algeria (ALG)                                      5
# Argentina (ARG)                                   18
# Armenia (ARM)                                      1
# Australasia (ANZ) [ANZ]                            3
# Australia (AUS) [AUS] [Z]                        139
# Austria (AUT)                                     18
# Azerbaijan (AZE)                                   6
# Bahamas (BAH)                                      5
# Bahrain (BRN)                                      0
# Barbados (BAR) [BAR]                               0
# Belarus (BLR)                                     12
# Belgium (BEL)                                     37
# Bermuda (BER)                                      0
# Bohemia (BOH) [BOH] [Z]                            0
# Botswana (BOT)                                     0
# Brazil (BRA)                                      23
# British West Indies (BWI) [BWI]                    0
# ...

# %%
df['Gold']>0
# Out:
# Afghanistan (AFG)                               False
# Algeria (ALG)                                    True
# Argentina (ARG)                                  True
# Armenia (ARM)                                    True
# Australasia (ANZ) [ANZ]                          True
# Australia (AUS) [AUS] [Z]                        True
# Austria (AUT)                                    True
# Azerbaijan (AZE)                                 True
# Bahamas (BAH)                                    True
# Bahrain (BRN)                                   False
# Barbados (BAR) [BAR]                            False
# Belarus (BLR)                                    True
# Belgium (BEL)                                    True
# Bermuda (BER)                                   False
# Bohemia (BOH) [BOH] [Z]                         False
# Botswana (BOT)                                  False
# Brazil (BRA)                                     True
# ...

# %%
df['Gold']+df['Sivler']+df['Bronze']
# Out:
# Afghanistan (AFG)                                   2
# Algeria (ALG)                                      15
# Argentina (ARG)                                    70
# Armenia (ARM)                                      12
# Australasia (ANZ) [ANZ]                            12
# Australia (AUS) [AUS] [Z]                         468
# Austria (AUT)                                      86
# Azerbaijan (AZE)                                   26
# Bahamas (BAH)                                      12
# Bahrain (BRN)                                       1
# Barbados (BAR) [BAR]                                1
# Belarus (BLR)                                      75
# Belgium (BEL)                                     142
# Bermuda (BER)                                       1
# Bohemia (BOH) [BOH] [Z]                             4
# Botswana (BOT)                                      1
# Brazil (BRA)                                      108
# ...

# %%
df = df.drop('Totals')

# %%
df['Gold'].max()
# Out:
# 976

# %%
df['Gold'].argmax()
# Out:
# 'United States\xa0(USA) [P] [Q] [R] [Z]'

# %%
only_gold = df.where(df['Gold']>0)

# %%
only_gold.head()
# Out:
#                          #Summer  Gold  Sivler  Bronze  #Winter  Gold.1  \
# Afghanistan (AFG)            NaN   NaN     NaN     NaN      NaN     NaN
# Algeria (ALG)               12.0   5.0     2.0     8.0      3.0     0.0
# Argentina (ARG)             23.0  18.0    24.0    28.0     18.0     0.0
# Armenia (ARM)                5.0   1.0     2.0     9.0      6.0     0.0
# Australasia (ANZ) [ANZ]      2.0   3.0     4.0     5.0      0.0     0.0
#
#                          Sivler.1  Bronze.1  Total.1  #Games  Gold.2  \
# Afghanistan (AFG)             NaN       NaN      NaN     NaN     NaN
# Algeria (ALG)                 0.0       0.0      0.0    15.0     5.0
# Argentina (ARG)               0.0       0.0      0.0    41.0    18.0
# Armenia (ARM)                 0.0       0.0      0.0    11.0     1.0
# Australasia (ANZ) [ANZ]       0.0       0.0      0.0     2.0     3.0
#
#                          Sivler.2  Bronze.2  Combined total
# ...

# %%
only_gold = only_gold.dropna()

# %%
only_gold.head()
# Out:
#                            #Summer   Gold  Sivler  Bronze  #Winter  Gold.1  \
# Algeria (ALG)                 12.0    5.0     2.0     8.0      3.0     0.0
# Argentina (ARG)               23.0   18.0    24.0    28.0     18.0     0.0
# Armenia (ARM)                  5.0    1.0     2.0     9.0      6.0     0.0
# Australasia (ANZ) [ANZ]        2.0    3.0     4.0     5.0      0.0     0.0
# Australia (AUS) [AUS] [Z]     25.0  139.0   152.0   177.0     18.0     5.0
#
#                            Sivler.1  Bronze.1  Total.1  #Games  Gold.2  \
# Algeria (ALG)                   0.0       0.0      0.0    15.0     5.0
# Argentina (ARG)                 0.0       0.0      0.0    41.0    18.0
# Armenia (ARM)                   0.0       0.0      0.0    11.0     1.0
# Australasia (ANZ) [ANZ]         0.0       0.0      0.0     2.0     3.0
# Australia (AUS) [AUS] [Z]       3.0       4.0     12.0    43.0   144.0
#
#                            Sivler.2  Bronze.2  Combined total
# ...

# %%
only_gold = df[df['Gold']>0]

# %%
only_gold.head()
# Out:
#                            #Summer  Gold  Sivler  Bronze  #Winter  Gold.1  \
# Algeria (ALG)                   12     5       2       8        3       0
# Argentina (ARG)                 23    18      24      28       18       0
# Armenia (ARM)                    5     1       2       9        6       0
# Australasia (ANZ) [ANZ]          2     3       4       5        0       0
# Australia (AUS) [AUS] [Z]       25   139     152     177       18       5
#
#                            Sivler.1  Bronze.1  Total.1  #Games  Gold.2  \
# Algeria (ALG)                     0         0        0      15       5
# Argentina (ARG)                   0         0        0      41      18
# Armenia (ARM)                     0         0        0      11       1
# Australasia (ANZ) [ANZ]           0         0        0       2       3
# Australia (AUS) [AUS] [Z]         3         4       12      43     144
#
#                            Sivler.2  Bronze.2  Combined total
# ...

# %%
df[(df['Gold'] > 0) | (df['Gold'] > 0)]
# Out:
#                                      #Summer  Gold  Sivler  Bronze  #Winter  \
# Algeria (ALG)                             12     5       2       8        3
# Argentina (ARG)                           23    18      24      28       18
# Armenia (ARM)                              5     1       2       9        6
# Australasia (ANZ) [ANZ]                    2     3       4       5        0
# Australia (AUS) [AUS] [Z]                 25   139     152     177       18
# Austria (AUT)                             26    18      33      35       22
# Azerbaijan (AZE)                           5     6       5      15        5
# Bahamas (BAH)                             15     5       2       5        0
# Belarus (BLR)                              5    12      24      39        6
# Belgium (BEL)                             25    37      52      53       20
# Brazil (BRA)                              21    23      30      55        7
# ...

# %%
df[(df['Gold'] > 0) & (df['Gold'] > 0)]
# Out:
#                                      #Summer  Gold  Sivler  Bronze  #Winter  \
# Algeria (ALG)                             12     5       2       8        3
# Argentina (ARG)                           23    18      24      28       18
# Armenia (ARM)                              5     1       2       9        6
# Australasia (ANZ) [ANZ]                    2     3       4       5        0
# Australia (AUS) [AUS] [Z]                 25   139     152     177       18
# Austria (AUT)                             26    18      33      35       22
# Azerbaijan (AZE)                           5     6       5      15        5
# Bahamas (BAH)                             15     5       2       5        0
# Belarus (BLR)                              5    12      24      39        6
# Belgium (BEL)                             25    37      52      53       20
# Brazil (BRA)                              21    23      30      55        7
# ...
